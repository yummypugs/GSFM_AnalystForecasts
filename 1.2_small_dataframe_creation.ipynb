# %%
import pandas as pd
import numpy as np
import datetime
import plotly.express as px

# %% [markdown]
# ## Whole Dataframe

# %%
df = pd.read_csv("Dataframes/economic_story_clean.csv")
df["Date"] = pd.to_datetime(df["Date"]).dt.date
df
#df.isna().sum()
# Out:
#       Instrument        Date  Earnings Per Share - Actual  \
# 0          AVY.N  2013-01-01                         0.54
# 1          AVY.N  2013-04-01                         0.59
# 2          AVY.N  2013-07-01                         0.71
# 3          AVY.N  2013-10-01                         0.69
# 4          AVY.N  2014-01-01                         0.69
# ...          ...         ...                          ...
# 19196    POOL.OQ  2021-10-01                         4.51
# 19197    POOL.OQ  2022-01-01                         2.63
# 19198    POOL.OQ  2022-04-01                         4.23
# 19199    POOL.OQ  2022-07-01                         7.63
# 19200    POOL.OQ  2022-10-01                         4.78
#
#        Earnings Per Share - Mean  Earnings Per Share - Actual Surprise  \
# 0                        0.48571                                11.178
# 1                        0.57571                                 2.482
# 2                        0.70250                                 1.068
# 3                        0.63833                                 8.095
# 4                        0.68000                                 1.471
# ...                          ...                                   ...
# 19196                    3.84833                                17.194
# 19197                    1.87500                                40.267
# 19198                    3.14867                                34.342
# 19199                    7.51700                                 1.503
# 19200                    4.58750                                 4.196
#
#        Earnings Per Share - Actual Surprise AbsVals GICS Industry Group Name  \
# 0                                            11.178                Materials
# 1                                             2.482                Materials
# 2                                             1.068                Materials
# 3                                             8.095                Materials
# 4                                             1.471                Materials
# ...                                             ...                      ...
# 19196                                        17.194                Retailing
# 19197                                        40.267                Retailing
# 19198                                        34.342                Retailing
# 19199                                         1.503                Retailing
# 19200                                         4.196                Retailing
#
#        Earnings Per Share – Coefficient of Variation  Market Capitalization  \
# 0                                           3.625620           3.426001e+09
# 1                                           2.046169           4.309428e+09
# 2                                           1.551601           4.258229e+09
# 3                                           2.775994           4.273414e+09
# 4                                           3.204412           4.877168e+09
# ...                                              ...                    ...
# 19196                                       2.836295           1.742020e+10
# 19197                                       3.269867           2.268979e+10
# 19198                                       6.630736           1.696712e+10
# 19199                                       3.625249           1.405795e+10
# 19200                                       3.843706           1.259813e+10
#
#        Revenue - Actual  ...  Recommendation change  \
# 0          1.532200e+09  ...                0.00000
# 1          1.498900e+09  ...               -0.12500
# 2          1.552300e+09  ...                0.00000
# 3          1.504900e+09  ...               -0.25000
# 4          1.583900e+09  ...               -0.29167
# ...                 ...  ...                    ...
# 19196      1.411448e+09  ...                0.00000
# 19197      1.035557e+09  ...                0.00000
# 19198      1.412650e+09  ...               -0.30000
# 19199      2.055818e+09  ...                0.20000
# 19200      1.615339e+09  ...                0.07273
#
#        Recommendation - Mean (1-5).1  Net Income after Tax  \
# 0                              3.000            33400000.0
# 1                              3.000            66800000.0
# 2                              2.875            70800000.0
# 3                              2.875            62000000.0
# 4                              2.625            42100000.0
# ...                              ...                   ...
# 19196                          2.300           184573000.0
# 19197                          2.300           107542000.0
# 19198                          2.300           179203000.0
# 19199                          2.000           307205000.0
# 19200                          2.200           189965000.0
#
#        Price Target - Mean  Price Target - Standard Deviation  Price Close  \
# 0                 36.00000                            2.44949        34.92
# 1                 42.57143                            3.92272        43.07
# 2                 45.00000                            4.30946        42.76
# 3                 47.71429                            3.45230        43.52
# 4                 54.62500                            3.42555        50.19
# ...                    ...                                ...          ...
# 19196            545.28571                           50.48823       434.41
# 19197            571.00000                           41.33833       566.00
# 19198            519.88889                           37.49206       422.85
# 19199            435.37500                           57.57373       351.23
# 19200            360.11111                           24.95082       318.21
#
#        Enterprise Value To Sales (Daily Time Series Ratio)  \
# 0                                               0.799347
# 1                                               0.895787
# 2                                               0.906078
# 3                                               0.903176
# 4                                               0.920659
# ...                                                  ...
# 19196                                           3.684400
# 19197                                           4.504382
# 19198                                           3.422880
# 19199                                           2.749481
# 19200                                           2.383926
#
#        3 Month Total Return    Volume  loss firm status
# 0                 10.637479  207295.0                -1
# 1                 24.148726       0.0                -1
# 2                 -0.054218       0.0                -1
# 3                  2.467620  236291.0                -1
# 4                 16.003852  157761.0                -1
# ...                     ...       ...               ...
# 19196             -5.130322  157740.0                -1
# 19197             30.489705   82349.0                -1
# 19198            -25.160664  290897.0                -1
# 19199            -21.661570  185584.0                -1
# 19200             -9.164375  238539.0                -1
#
# [19201 rows x 23 columns]

# %% [markdown]
# # Creating subset dataframes for every factor

# %% [markdown]
# ## Characteristics dataframe

# %%
characteristics = df.loc[:, ["Instrument", "Date","GICS Industry Group Name", "Earnings Per Share - Actual Surprise", "Earnings Per Share - Actual Surprise AbsVals", "Revenue - Actual", "Enterprise Value", "Market Capitalization", "Enterprise Value To Sales (Daily Time Series Ratio)", "3 Month Total Return", "Volume", "loss firm status"]]
characteristics
# Out:
#       Instrument        Date GICS Industry Group Name  \
# 0          AVY.N  2013-01-01                Materials
# 1          AVY.N  2013-04-01                Materials
# 2          AVY.N  2013-07-01                Materials
# 3          AVY.N  2013-10-01                Materials
# 4          AVY.N  2014-01-01                Materials
# ...          ...         ...                      ...
# 19196    POOL.OQ  2021-10-01                Retailing
# 19197    POOL.OQ  2022-01-01                Retailing
# 19198    POOL.OQ  2022-04-01                Retailing
# 19199    POOL.OQ  2022-07-01                Retailing
# 19200    POOL.OQ  2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  \
# 0                                    11.178
# 1                                     2.482
# 2                                     1.068
# 3                                     8.095
# 4                                     1.471
# ...                                     ...
# 19196                                17.194
# 19197                                40.267
# 19198                                34.342
# 19199                                 1.503
# 19200                                 4.196
#
#        Earnings Per Share - Actual Surprise AbsVals  Revenue - Actual  \
# 0                                            11.178      1.532200e+09
# 1                                             2.482      1.498900e+09
# 2                                             1.068      1.552300e+09
# 3                                             8.095      1.504900e+09
# 4                                             1.471      1.583900e+09
# ...                                             ...               ...
# 19196                                        17.194      1.411448e+09
# 19197                                        40.267      1.035557e+09
# 19198                                        34.342      1.412650e+09
# 19199                                         1.503      2.055818e+09
# 19200                                         4.196      1.615339e+09
#
#        Enterprise Value  Market Capitalization  \
# 0          4.413001e+09           3.426001e+09
# 1          5.459128e+09           4.309428e+09
# 2          5.436229e+09           4.258229e+09
# 3          5.029514e+09           4.273414e+09
# 4          5.553068e+09           4.877168e+09
# ...                 ...                    ...
# 19196      1.769954e+10           1.742020e+10
# 19197      2.384882e+10           2.268979e+10
# 19198      1.843682e+10           1.696712e+10
# 19199      1.556187e+10           1.405795e+10
# 19200      1.406160e+10           1.259813e+10
#
#        Enterprise Value To Sales (Daily Time Series Ratio)  \
# 0                                               0.799347
# 1                                               0.895787
# 2                                               0.906078
# 3                                               0.903176
# 4                                               0.920659
# ...                                                  ...
# 19196                                           3.684400
# 19197                                           4.504382
# 19198                                           3.422880
# 19199                                           2.749481
# 19200                                           2.383926
#
#        3 Month Total Return    Volume  loss firm status
# 0                 10.637479  207295.0                -1
# 1                 24.148726       0.0                -1
# 2                 -0.054218       0.0                -1
# 3                  2.467620  236291.0                -1
# 4                 16.003852  157761.0                -1
# ...                     ...       ...               ...
# 19196             -5.130322  157740.0                -1
# 19197             30.489705   82349.0                -1
# 19198            -25.160664  290897.0                -1
# 19199            -21.661570  185584.0                -1
# 19200             -9.164375  238539.0                -1
#
# [19201 rows x 12 columns]

# %%
characteristics.to_csv("Dataframes/characteristics.csv", index=False)

# %% [markdown]
# ## Analyst characteristics dataframe

# %%
analysts = df.loc[:, ["Instrument", "Date","GICS Industry Group Name", "Earnings Per Share - Actual Surprise", "Earnings Per Share - Actual Surprise AbsVals", "Earnings Per Share – Coefficient of Variation", "Number of Analysts", "Recommendation - Mean (1-5)", "Recommendation change", "Recommendation - Mean (1-5).1", "Price Target - Mean", "Price Target - Standard Deviation"]]
#analysts

# %%
analysts
# Out:
#       Instrument        Date GICS Industry Group Name  \
# 0          AVY.N  2013-01-01                Materials
# 1          AVY.N  2013-04-01                Materials
# 2          AVY.N  2013-07-01                Materials
# 3          AVY.N  2013-10-01                Materials
# 4          AVY.N  2014-01-01                Materials
# ...          ...         ...                      ...
# 19196    POOL.OQ  2021-10-01                Retailing
# 19197    POOL.OQ  2022-01-01                Retailing
# 19198    POOL.OQ  2022-04-01                Retailing
# 19199    POOL.OQ  2022-07-01                Retailing
# 19200    POOL.OQ  2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  \
# 0                                    11.178
# 1                                     2.482
# 2                                     1.068
# 3                                     8.095
# 4                                     1.471
# ...                                     ...
# 19196                                17.194
# 19197                                40.267
# 19198                                34.342
# 19199                                 1.503
# 19200                                 4.196
#
#        Earnings Per Share - Actual Surprise AbsVals  \
# 0                                            11.178
# 1                                             2.482
# 2                                             1.068
# 3                                             8.095
# 4                                             1.471
# ...                                             ...
# 19196                                        17.194
# 19197                                        40.267
# 19198                                        34.342
# 19199                                         1.503
# 19200                                         4.196
#
#        Earnings Per Share – Coefficient of Variation  Number of Analysts  \
# 0                                           3.625620                 7.0
# 1                                           2.046169                 7.0
# 2                                           1.551601                 8.0
# 3                                           2.775994                 7.0
# 4                                           3.204412                 8.0
# ...                                              ...                 ...
# 19196                                       2.836295                 8.0
# 19197                                       3.269867                 8.0
# 19198                                       6.630736                 9.0
# 19199                                       3.625249                 9.0
# 19200                                       3.843706                10.0
#
#        Recommendation - Mean (1-5)  Recommendation change  \
# 0                          3.00000                0.00000
# 1                          2.87500               -0.12500
# 2                          2.87500                0.00000
# 3                          2.62500               -0.25000
# 4                          2.33333               -0.29167
# ...                            ...                    ...
# 19196                      2.30000                0.00000
# 19197                      2.30000                0.00000
# 19198                      2.00000               -0.30000
# 19199                      2.20000                0.20000
# 19200                      2.27273                0.07273
#
#        Recommendation - Mean (1-5).1  Price Target - Mean  \
# 0                              3.000             36.00000
# 1                              3.000             42.57143
# 2                              2.875             45.00000
# 3                              2.875             47.71429
# 4                              2.625             54.62500
# ...                              ...                  ...
# 19196                          2.300            545.28571
# 19197                          2.300            571.00000
# 19198                          2.300            519.88889
# 19199                          2.000            435.37500
# 19200                          2.200            360.11111
#
#        Price Target - Standard Deviation
# 0                                2.44949
# 1                                3.92272
# 2                                4.30946
# 3                                3.45230
# 4                                3.42555
# ...                                  ...
# 19196                           50.48823
# 19197                           41.33833
# 19198                           37.49206
# 19199                           57.57373
# 19200                           24.95082
#
# [19201 rows x 12 columns]

# %%
analysts.to_csv("Dataframes/analysts.csv", index=False)

# %% [markdown]
# ## Macroeconomic factors dataframe
#
# Import the dataframe and show it atleast

# %%
macro = df.loc[:, ["Instrument", "Date","GICS Industry Group Name", "Earnings Per Share - Actual Surprise", "Earnings Per Share - Actual Surprise AbsVals"]]
macro
# Out:
#       Instrument        Date GICS Industry Group Name  \
# 0          AVY.N  2013-01-01                Materials
# 1          AVY.N  2013-04-01                Materials
# 2          AVY.N  2013-07-01                Materials
# 3          AVY.N  2013-10-01                Materials
# 4          AVY.N  2014-01-01                Materials
# ...          ...         ...                      ...
# 19196    POOL.OQ  2021-10-01                Retailing
# 19197    POOL.OQ  2022-01-01                Retailing
# 19198    POOL.OQ  2022-04-01                Retailing
# 19199    POOL.OQ  2022-07-01                Retailing
# 19200    POOL.OQ  2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  \
# 0                                    11.178
# 1                                     2.482
# 2                                     1.068
# 3                                     8.095
# 4                                     1.471
# ...                                     ...
# 19196                                17.194
# 19197                                40.267
# 19198                                34.342
# 19199                                 1.503
# 19200                                 4.196
#
#        Earnings Per Share - Actual Surprise AbsVals
# 0                                            11.178
# 1                                             2.482
# 2                                             1.068
# 3                                             8.095
# 4                                             1.471
# ...                                             ...
# 19196                                        17.194
# 19197                                        40.267
# 19198                                        34.342
# 19199                                         1.503
# 19200                                         4.196
#
# [19201 rows x 5 columns]

# %%
macro.to_csv("Dataframes/macro_just_date.csv", index=False)

# %%
macro.shape
# Out:
# (19201, 5)
