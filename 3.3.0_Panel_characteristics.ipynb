# %% [markdown]
# # Panle Regression - Firm Characteristics

# %% [markdown]
# ### Random Effects Panel Regression

# %%
import pandas as pd
import numpy as np
import datetime as dt
import sklearn
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from linearmodels.panel import PanelOLS
from linearmodels.panel import RandomEffects

# %% [markdown]
# Data

# %%
df = pd.read_csv("Dataframes/characteristics.csv")
X_var_names = ["Revenue - Actual","Enterprise Value","Market Capitalization","loss firm status", "Enterprise Value To Sales (Daily Time Series Ratio)", "3 Month Total Return", "Volume"]
df
# Out:
#       Instrument        Date GICS Industry Group Name  \
# 0          AVY.N  2013-01-01                Materials
# 1          AVY.N  2013-04-01                Materials
# 2          AVY.N  2013-07-01                Materials
# 3          AVY.N  2013-10-01                Materials
# 4          AVY.N  2014-01-01                Materials
# ...          ...         ...                      ...
# 19335    POOL.OQ  2021-10-01                Retailing
# 19336    POOL.OQ  2022-01-01                Retailing
# 19337    POOL.OQ  2022-04-01                Retailing
# 19338    POOL.OQ  2022-07-01                Retailing
# 19339    POOL.OQ  2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  Revenue - Actual  \
# 0                                    11.178      1.532200e+09
# 1                                     2.482      1.498900e+09
# 2                                     1.068      1.552300e+09
# 3                                     8.095      1.504900e+09
# 4                                     1.471      1.583900e+09
# ...                                     ...               ...
# 19335                                17.194      1.411448e+09
# 19336                                40.267      1.035557e+09
# 19337                                34.342      1.412650e+09
# 19338                                 1.503      2.055818e+09
# 19339                                 4.196      1.615339e+09
#
#        Enterprise Value  Market Capitalization  \
# 0          4.413001e+09           3.426001e+09
# 1          5.459128e+09           4.309428e+09
# 2          5.436229e+09           4.258229e+09
# 3          5.029514e+09           4.273414e+09
# 4          5.553068e+09           4.877168e+09
# ...                 ...                    ...
# 19335      1.769954e+10           1.742020e+10
# 19336      2.384882e+10           2.268979e+10
# 19337      1.843682e+10           1.696712e+10
# 19338      1.556187e+10           1.405795e+10
# 19339      1.406160e+10           1.259813e+10
#
#        Enterprise Value To Sales (Daily Time Series Ratio)  \
# 0                                               0.799347
# 1                                               0.895787
# 2                                               0.906078
# 3                                               0.903176
# 4                                               0.920659
# ...                                                  ...
# 19335                                           3.684400
# 19336                                           4.504382
# 19337                                           3.422880
# 19338                                           2.749481
# 19339                                           2.383926
#
#        3 Month Total Return    Volume  loss firm status
# 0                 10.637479  207295.0                -1
# 1                 24.148726       0.0                -1
# 2                 -0.054218       0.0                -1
# 3                  2.467620  236291.0                -1
# 4                 16.003852  157761.0                -1
# ...                     ...       ...               ...
# 19335             -5.130322  157740.0                -1
# 19336             30.489705   82349.0                -1
# 19337            -25.160664  290897.0                -1
# 19338            -21.661570  185584.0                -1
# 19339             -9.164375  238539.0                -1
#
# [19340 rows x 11 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %% [markdown]
# Remove outliers

# %%
#removing outliers
summary_stats = df["Earnings Per Share - Actual Surprise"].describe()
Q1 = summary_stats.loc['25%']
Q3 = summary_stats.loc['75%']
IQR = Q3 - Q1
threshold = 7
surprise_outliers_removed = df["Earnings Per Share - Actual Surprise"].loc[~((df["Earnings Per Share - Actual Surprise"] < (Q1 - threshold * IQR)) | (df["Earnings Per Share - Actual Surprise"] > (Q3 + threshold * IQR)))]
df_clean = df.copy()
df_clean["Earnings Per Share - Actual Surprise"] = surprise_outliers_removed
df_clean = df_clean.dropna(subset=["Earnings Per Share - Actual Surprise"])
#df_clean = df_clean.dropna()
df_clean
# Out:
#       Instrument       Date GICS Industry Group Name  \
# 0          AVY.N 2013-01-01                Materials
# 1          AVY.N 2013-04-01                Materials
# 2          AVY.N 2013-07-01                Materials
# 3          AVY.N 2013-10-01                Materials
# 4          AVY.N 2014-01-01                Materials
# ...          ...        ...                      ...
# 19335    POOL.OQ 2021-10-01                Retailing
# 19336    POOL.OQ 2022-01-01                Retailing
# 19337    POOL.OQ 2022-04-01                Retailing
# 19338    POOL.OQ 2022-07-01                Retailing
# 19339    POOL.OQ 2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  Revenue - Actual  \
# 0                                    11.178      1.532200e+09
# 1                                     2.482      1.498900e+09
# 2                                     1.068      1.552300e+09
# 3                                     8.095      1.504900e+09
# 4                                     1.471      1.583900e+09
# ...                                     ...               ...
# 19335                                17.194      1.411448e+09
# 19336                                40.267      1.035557e+09
# 19337                                34.342      1.412650e+09
# 19338                                 1.503      2.055818e+09
# 19339                                 4.196      1.615339e+09
#
#        Enterprise Value  Market Capitalization  \
# 0          4.413001e+09           3.426001e+09
# 1          5.459128e+09           4.309428e+09
# 2          5.436229e+09           4.258229e+09
# 3          5.029514e+09           4.273414e+09
# 4          5.553068e+09           4.877168e+09
# ...                 ...                    ...
# 19335      1.769954e+10           1.742020e+10
# 19336      2.384882e+10           2.268979e+10
# 19337      1.843682e+10           1.696712e+10
# 19338      1.556187e+10           1.405795e+10
# 19339      1.406160e+10           1.259813e+10
#
#        Enterprise Value To Sales (Daily Time Series Ratio)  \
# 0                                               0.799347
# 1                                               0.895787
# 2                                               0.906078
# 3                                               0.903176
# 4                                               0.920659
# ...                                                  ...
# 19335                                           3.684400
# 19336                                           4.504382
# 19337                                           3.422880
# 19338                                           2.749481
# 19339                                           2.383926
#
#        3 Month Total Return    Volume  loss firm status
# 0                 10.637479  207295.0                -1
# 1                 24.148726       0.0                -1
# 2                 -0.054218       0.0                -1
# 3                  2.467620  236291.0                -1
# 4                 16.003852  157761.0                -1
# ...                     ...       ...               ...
# 19335             -5.130322  157740.0                -1
# 19336             30.489705   82349.0                -1
# 19337            -25.160664  290897.0                -1
# 19338            -21.661570  185584.0                -1
# 19339             -9.164375  238539.0                -1
#
# [18569 rows x 11 columns]

# %% [markdown]
# Standardising

# %%
rescale = df_clean
#rescale["Earnings Per Share - Actual Surprise"] = MinMaxScaler().fit_transform(np.array(rescale["Earnings Per Share - Actual Surprise"]).reshape(-1,1))
rescale["Revenue - Actual"] = MinMaxScaler().fit_transform(np.array(rescale["Revenue - Actual"]).reshape(-1,1))
rescale["Enterprise Value"] = MinMaxScaler().fit_transform(np.array(rescale["Enterprise Value"]).reshape(-1,1))
rescale["Market Capitalization"] = MinMaxScaler().fit_transform(np.array(rescale["Market Capitalization"]).reshape(-1,1))
rescale["Enterprise Value To Sales (Daily Time Series Ratio)"] = MinMaxScaler().fit_transform(np.array(rescale["Enterprise Value To Sales (Daily Time Series Ratio)"]).reshape(-1,1))
rescale["3 Month Total Return"] = MinMaxScaler().fit_transform(np.array(rescale["3 Month Total Return"]).reshape(-1,1))
rescale["Volume"] = MinMaxScaler().fit_transform(np.array(rescale["Volume"]).reshape(-1,1))
df_clean = rescale
df_clean
# Out:
#       Instrument       Date GICS Industry Group Name  \
# 0          AVY.N 2013-01-01                Materials
# 1          AVY.N 2013-04-01                Materials
# 2          AVY.N 2013-07-01                Materials
# 3          AVY.N 2013-10-01                Materials
# 4          AVY.N 2014-01-01                Materials
# ...          ...        ...                      ...
# 19335    POOL.OQ 2021-10-01                Retailing
# 19336    POOL.OQ 2022-01-01                Retailing
# 19337    POOL.OQ 2022-04-01                Retailing
# 19338    POOL.OQ 2022-07-01                Retailing
# 19339    POOL.OQ 2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  Revenue - Actual  \
# 0                                    11.178          0.065123
# 1                                     2.482          0.064917
# 2                                     1.068          0.065247
# 3                                     8.095          0.064955
# 4                                     1.471          0.065443
# ...                                     ...               ...
# 19335                                17.194          0.064377
# 19336                                40.267          0.062055
# 19337                                34.342          0.064385
# 19338                                 1.503          0.068358
# 19339                                 4.196          0.065637
#
#        Enterprise Value  Market Capitalization  \
# 0              0.027862               0.001166
# 1              0.028207               0.001471
# 2              0.028199               0.001453
# 3              0.028065               0.001459
# 4              0.028238               0.001667
# ...                 ...                    ...
# 19335          0.032245               0.006004
# 19336          0.034274               0.007826
# 19337          0.032488               0.005848
# 19338          0.031540               0.004842
# 19339          0.031045               0.004337
#
#        Enterprise Value To Sales (Daily Time Series Ratio)  \
# 0                                               0.027195
# 1                                               0.027308
# 2                                               0.027321
# 3                                               0.027317
# 4                                               0.027338
# ...                                                  ...
# 19335                                           0.030598
# 19336                                           0.031566
# 19337                                           0.030290
# 19338                                           0.029495
# 19339                                           0.029064
#
#        3 Month Total Return    Volume  loss firm status
# 0                  0.298034  0.001183                -1
# 1                  0.340793  0.000000                -1
# 2                  0.264198  0.000000                -1
# 3                  0.272179  0.001348                -1
# 4                  0.315017  0.000900                -1
# ...                     ...       ...               ...
# 19335              0.248134  0.000900                -1
# 19336              0.360861  0.000470                -1
# 19337              0.184744  0.001660                -1
# 19338              0.195817  0.001059                -1
# 19339              0.235367  0.001361                -1
#
# [18569 rows x 11 columns]

# %%
df_panel = df_clean.copy()

# %% [markdown]
# #### Random Effects

# %%
# turn dataframe into right dimension for panel regression with multiindex
df_clean['Instrument'] = df_clean['Instrument'].astype('category')
df_clean['Date'] = pd.to_datetime(df_clean['Date'])

# set the index to be the time variable and the cross-sectional variable
df_clean.set_index(['Instrument', 'Date'], inplace=True)

# define the dependent variable
y = df_clean.loc[:, "Earnings Per Share - Actual Surprise"]
X = df_clean[X_var_names]

# perform the random effects panel regression
random_effects_model = RandomEffects(y, X)

# fit the model and print the summary statistics
random_effects_results = random_effects_model.fit()
print(random_effects_results.summary)
# Out:
#                                  RandomEffects Estimation Summary
# ==================================================================================================
# Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.0525
# Estimator:                                RandomEffects   R-squared (Between):              0.5975
# No. Observations:                                 18569   R-squared (Within):               0.0141
# Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.1531
# Time:                                          20:49:30   Log-likelihood                -7.821e+04
# Cov. Estimator:                              Unadjusted
#                                                           F-statistic:                      146.84
# Entities:                                           501   P-value                           0.0000
# Avg Obs:                                         37.064   Distribution:                 F(7,18562)
# Min Obs:                                         6.0000
# Max Obs:                                         40.000   F-statistic (robust):             146.84
#                                                           P-value                           0.0000
# Time periods:                                        41   Distribution:                 F(7,18562)
# Avg Obs:                                         452.90
# Min Obs:                                         47.000
# Max Obs:                                         490.00
#
#                                                   Parameter Estimates
# =======================================================================================================================
#                                                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------------------------------------
# Revenue - Actual                                        1.2730     3.7021     0.3439     0.7309     -5.9834      8.5294
# Enterprise Value                                       -53.047     17.181    -3.0875     0.0020     -86.723     -19.370
# Market Capitalization                                   66.172     16.378     4.0403     0.0001      34.069      98.274
# loss firm status                                       -0.5312     0.2503    -2.1225     0.0338     -1.0217     -0.0407
# Enterprise Value To Sales (Daily Time Series Ratio)    -30.114     10.055    -2.9951     0.0027     -49.822     -10.406
# 3 Month Total Return                                    32.334     1.9066     16.959     0.0000      28.597      36.071
# Volume                                                  17.170     8.6624     1.9821     0.0475      0.1904      34.149
# =======================================================================================================================

# %% [markdown]
# **R-squared (Within)**: This is the proportion of variation in the dependent variable (in your case, Earnings Per Share - Actual Surprise) that is explained by the independent variables (in our case, the variables in X) within each individual instrument (the 501 companies). In other words, this R-squared measures how well the independent variables explain the variation in the dependent variable (surprise) within each instrument. The R-squared (Within) is 0.0141, which means that the independent variables explain 0.141% of the variation in the dependent variable within each instrument.
#
# **R-squared (Between)**: This is the proportion of variation in the dependent variable that is explained by the independent variables across the instruments. In other words, this R-squared measures how well the independent variables explain the variation in the dependent variable between different instruments. The R-squared (Between) is 0.5975, which means that the independent variables actually explain the variation in the dependent variable across instruments quite well (to 59.75%).
#
# **R-squared (Overall)**: This is the proportion of variation in the dependent variable that is explained by the independent variables overall, taking into account both the within-instrument and between-instrument variation. The R-squared (Overall) is 0.1531, which means that the independent variables explain only about 2.74% of the variation in the dependent variable overall.

# %% [markdown]
# #### Fixed Effects

# %%
y = df_clean.loc[:, "Earnings Per Share - Actual Surprise"]
X = df_clean[X_var_names]

# perform the fixed effects panel regression
fixed_effects_model = PanelOLS(y, X, entity_effects=True, time_effects=True)

# fit the model and print the summary statistics
fixed_effects_results = fixed_effects_model.fit()
fixed_effects_results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                                    PanelOLS Estimation Summary
# ==================================================================================================
# Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.0091
# Estimator:                                     PanelOLS   R-squared (Between):              0.5647
# No. Observations:                                 18569   R-squared (Within):               0.0137
# Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.1448
# Time:                                          20:49:37   Log-likelihood                -7.762e+04
# Cov. Estimator:                              Unadjusted
#                                                           F-statistic:                      23.591
# Entities:                                           501   P-value                           0.0000
# Avg Obs:                                         37.064   Distribution:                 F(7,18021)
# Min Obs:                                         6.0000
# Max Obs:                                         40.000   F-statistic (robust):             23.591
#                                                           P-value                           0.0000
# Time periods:                                        41   Distribution:                 F(7,18021)
# Avg Obs:                                         452.90
# Min Obs:                                         47.000
# Max Obs:                                         490.00
#
#                                                   Parameter Estimates
# =======================================================================================================================
#                                                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------------------------------------
# Revenue - Actual                                        23.627     6.7639     3.4931     0.0005      10.369      36.885
# Enterprise Value                                       -90.805     32.207    -2.8194     0.0048     -153.93     -27.676
# Market Capitalization                                   82.666     31.240     2.6462     0.0081      21.433      143.90
# loss firm status                                       -1.2540     0.2607    -4.8096     0.0000     -1.7651     -0.7430
# Enterprise Value To Sales (Daily Time Series Ratio)    -41.310     10.797    -3.8260     0.0001     -62.474     -20.147
# 3 Month Total Return                                    29.022     2.9316     9.8995     0.0000      23.275      34.768
# Volume                                                  7.8320     9.6007     0.8158     0.4146     -10.986      26.650
# =======================================================================================================================
#
# F-test for Poolability: 4.9788
# P-value: 0.0000
# Distribution: F(540,18021)
#
# Included effects: Entity, Time
# """

# %% [markdown]
# By Industry: example tech industry

# %%
df2 = df_panel[df_panel['GICS Industry Group Name'] == 'Technology Hardware & Equipment']
groups = df2.groupby('Instrument')

def panel_regression_random(group):
    if len(group) < 2:
        return None
    
    group['Instrument'] = group['Instrument'].astype('category')
    group['Date'] = pd.to_datetime(group['Date'])
    group.set_index(['Instrument', 'Date'], inplace=True)

    y = group.loc[:, "Earnings Per Share - Actual Surprise"]
    X = group[X_var_names]

    model = RandomEffects(y, X).fit()
    return model


results_random = groups.apply(panel_regression_random)
results_random = results_random.dropna()
models_random = results_random.tolist()
models_random
# Out:
# [                                 RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4285
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.4285
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.4285
#  Time:                                          20:49:47   Log-likelihood                   -132.40
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.1245
#  Entities:                                             1   P-value                           0.0034
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             4.1245
#                                                            P-value                           0.0034
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -4.4418     14.961    -0.2969     0.7684     -34.880      25.997
#  Enterprise Value                                       -21.255     199.94    -0.1063     0.9160     -428.03      385.52
#  Market Capitalization                                  -31.551     198.99    -0.1586     0.8750     -436.39      373.29
#  loss firm status                                        231.39     61.073     3.7888     0.0006      107.14      355.65
#  Enterprise Value To Sales (Daily Time Series Ratio)     8575.9     2275.4     3.7690     0.0006      3946.6   1.321e+04
#  3 Month Total Return                                   -24.264     27.532    -0.8813     0.3845     -80.278      31.749
#  Volume                                                  2.3643     9.3570     0.2527     0.8021     -16.673      21.401
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18884d510,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.8297
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    33   R-squared (Within):               0.4415
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.8297
#  Time:                                          20:49:47   Log-likelihood                   -115.93
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      18.094
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         33.000   Distribution:                    F(7,26)
#  Min Obs:                                         33.000
#  Max Obs:                                         33.000   F-statistic (robust):             18.094
#                                                            P-value                           0.0000
#  Time periods:                                        33   Distribution:                    F(7,26)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        3409.0     2938.3     1.1602     0.2565     -2630.7      9448.7
#  Enterprise Value                                     -1.09e+04     7592.9    -1.4353     0.1631  -2.651e+04      4709.6
#  Market Capitalization                                   4929.3     4960.4     0.9937     0.3295     -5266.9   1.513e+04
#  loss firm status                                       -3.8842     4.8577    -0.7996     0.4312     -13.869      6.1010
#  Enterprise Value To Sales (Daily Time Series Ratio)     3589.1     1422.9     2.5223     0.0181      664.22      6514.0
#  3 Month Total Return                                   -3.8957     26.709    -0.1459     0.8852     -58.798      51.006
#  Volume                                                 -849.79     1049.7    -0.8095     0.4256     -3007.6      1308.0
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x188843a50,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4378
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.4378
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.4378
#  Time:                                          20:49:47   Log-likelihood                   -118.09
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.2823
#  Entities:                                             1   P-value                           0.0027
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             4.2823
#                                                            P-value                           0.0027
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        2685.4     1207.0     2.2248     0.0330      229.70      5141.2
#  Enterprise Value                                       -4666.9     6558.3    -0.7116     0.4817  -1.801e+04      8676.2
#  Market Capitalization                                   1888.3     6857.0     0.2754     0.7847  -1.206e+04   1.584e+04
#  loss firm status                                        215.98     239.99     0.8999     0.3747     -272.29      704.25
#  Enterprise Value To Sales (Daily Time Series Ratio)     5395.7     3736.6     1.4440     0.1582     -2206.5     1.3e+04
#  3 Month Total Return                                    83.474     29.126     2.8660     0.0072      24.217      142.73
#  Volume                                                  418.67     270.75     1.5463     0.1316     -132.17      969.51
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x188835050,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.7072
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    36   R-squared (Within):               0.1032
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.7072
#  Time:                                          20:49:47   Log-likelihood                   -111.37
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      10.007
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         36.000   Distribution:                    F(7,29)
#  Min Obs:                                         36.000
#  Max Obs:                                         36.000   F-statistic (robust):             10.007
#                                                            P-value                           0.0000
#  Time periods:                                        36   Distribution:                    F(7,29)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -139.78     640.30    -0.2183     0.8287     -1449.3      1169.8
#  Enterprise Value                                       -5216.4     5848.9    -0.8919     0.3798  -1.718e+04      6745.9
#  Market Capitalization                                   5102.6     4505.4     1.1325     0.2667     -4112.1   1.432e+04
#  loss firm status                                       -0.2793     3.4764    -0.0803     0.9365     -7.3893      6.8306
#  Enterprise Value To Sales (Daily Time Series Ratio)     5794.6     5201.8     1.1140     0.2744     -4844.2   1.643e+04
#  3 Month Total Return                                    10.534     35.237     0.2990     0.7671     -61.533      82.602
#  Volume                                                  110.35     831.22     0.1328     0.8953     -1589.7      1810.4
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18882f1d0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.2207
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.2207
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.2207
#  Time:                                          20:49:47   Log-likelihood                   -90.217
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      1.5576
#  Entities:                                             1   P-value                           0.1907
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             1.5576
#                                                            P-value                           0.1907
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -276.29     155.04    -1.7821     0.0839     -591.72      39.133
#  Enterprise Value                                        433.93     259.85     1.6699     0.1044     -94.743      962.61
#  Market Capitalization                                  -387.48     245.41    -1.5789     0.1239     -886.76      111.80
#  loss firm status                                       -71.383     45.559    -1.5668     0.1267     -164.07      21.308
#  Enterprise Value To Sales (Daily Time Series Ratio)    -1452.5     1667.5    -0.8711     0.3900     -4845.1      1940.0
#  3 Month Total Return                                    6.7388     15.202     0.4433     0.6605     -24.190      37.667
#  Volume                                                  16.406     21.618     0.7589     0.4533     -27.575      60.387
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18881c8d0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.2909
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.2909
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.2909
#  Time:                                          20:49:47   Log-likelihood                   -105.15
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      2.2562
#  Entities:                                             1   P-value                           0.0620
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             2.2562
#                                                            P-value                           0.0620
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        4935.2     4286.5     1.1513     0.2579     -3785.8   1.366e+04
#  Enterprise Value                                     1.646e+04     9324.0     1.7655     0.0867     -2507.9   3.543e+04
#  Market Capitalization                               -1.852e+04     8454.0    -2.1906     0.0357  -3.572e+04     -1319.4
#  loss firm status                                        731.51     316.94     2.3080     0.0274      86.690      1376.3
#  Enterprise Value To Sales (Daily Time Series Ratio)     839.48     2775.9     0.3024     0.7642     -4808.0      6487.0
#  3 Month Total Return                                   -5.7077     14.628    -0.3902     0.6989     -35.469      24.054
#  Volume                                                 -986.90     838.28    -1.1773     0.2475     -2692.4      718.58
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1888163d0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5874
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    39   R-squared (Within):               0.1690
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.5874
#  Time:                                          20:49:47   Log-likelihood                   -121.91
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      6.5070
#  Entities:                                             1   P-value                           0.0001
#  Avg Obs:                                         39.000   Distribution:                    F(7,32)
#  Min Obs:                                         39.000
#  Max Obs:                                         39.000   F-statistic (robust):             6.5070
#                                                            P-value                           0.0001
#  Time periods:                                        39   Distribution:                    F(7,32)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        195.33     669.46     0.2918     0.7723     -1168.3      1559.0
#  Enterprise Value                                       -789.58     1658.2    -0.4762     0.6372     -4167.2      2588.0
#  Market Capitalization                                  -1349.1     1422.0    -0.9487     0.3499     -4245.6      1547.5
#  loss firm status                                        0.1016     2.2601     0.0450     0.9644     -4.5020      4.7052
#  Enterprise Value To Sales (Daily Time Series Ratio)     823.09     1101.0     0.7476     0.4602     -1419.6      3065.8
#  3 Month Total Return                                    31.356     32.337     0.9697     0.3395     -34.512      97.225
#  Volume                                                 -87.993     165.01    -0.5333     0.5975     -424.10      248.12
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887fc190,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.6427
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    27   R-squared (Within):               0.4492
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.6427
#  Time:                                          20:49:47   Log-likelihood                   -101.25
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      5.1400
#  Entities:                                             1   P-value                           0.0018
#  Avg Obs:                                         27.000   Distribution:                    F(7,20)
#  Min Obs:                                         27.000
#  Max Obs:                                         27.000   F-statistic (robust):             5.1400
#                                                            P-value                           0.0018
#  Time periods:                                        27   Distribution:                    F(7,20)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -487.44     336.90    -1.4468     0.1634     -1190.2      215.32
#  Enterprise Value                                       -5031.1     7242.2    -0.6947     0.4952  -2.014e+04   1.008e+04
#  Market Capitalization                                   4286.6     5032.1     0.8519     0.4044     -6210.1   1.478e+04
#  loss firm status                                       -7.6743     3.9620    -1.9370     0.0670     -15.939      0.5903
#  Enterprise Value To Sales (Daily Time Series Ratio)     6386.6     8455.4     0.7553     0.4589  -1.125e+04   2.402e+04
#  3 Month Total Return                                    121.87     51.877     2.3493     0.0292      13.659      230.08
#  Volume                                                 -101.55     360.32    -0.2818     0.7810     -853.16      650.06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887f1610,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5011
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.3759
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.5011
#  Time:                                          20:49:47   Log-likelihood                   -138.49
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.7353
#  Entities:                                             1   P-value                           0.0009
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             4.7353
#                                                            P-value                           0.0009
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        325.09     109.01     2.9822     0.0053      103.31      546.87
#  Enterprise Value                                       -3925.6     1727.1    -2.2730     0.0297     -7439.3     -411.85
#  Market Capitalization                                   1305.2     1367.4     0.9545     0.3468     -1476.7      4087.2
#  loss firm status                                       -9.3275     5.9971    -1.5553     0.1294     -21.529      2.8736
#  Enterprise Value To Sales (Daily Time Series Ratio)     2782.4     1534.9     1.8127     0.0790     -340.42      5905.2
#  3 Month Total Return                                    19.224     29.415     0.6536     0.5179     -40.620      79.069
#  Volume                                                  79.329     126.94     0.6249     0.5363     -178.94      337.60
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887f1210,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.6369
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.4111
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.6369
#  Time:                                          20:49:47   Log-likelihood                   -136.78
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      8.2678
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             8.2678
#                                                            P-value                           0.0000
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        3612.6     2528.4     1.4288     0.1625     -1531.5      8756.6
#  Enterprise Value                                    -2.043e+04  1.139e+04    -1.7944     0.0819   -4.36e+04      2734.0
#  Market Capitalization                                   8914.5     5150.0     1.7310     0.0928     -1563.3   1.939e+04
#  loss firm status                                        10.410     3.1846     3.2689     0.0025      3.9309      16.889
#  Enterprise Value To Sales (Daily Time Series Ratio)   1.19e+04  1.127e+04     1.0560     0.2987  -1.103e+04   3.484e+04
#  3 Month Total Return                                    80.357     46.224     1.7384     0.0915     -13.687      174.40
#  Volume                                                 -124.24     394.84    -0.3147     0.7550     -927.55      679.07
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887dcd50,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5638
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    32   R-squared (Within):               0.1951
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.5638
#  Time:                                          20:49:47   Log-likelihood                   -120.77
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.6162
#  Entities:                                             1   P-value                           0.0020
#  Avg Obs:                                         32.000   Distribution:                    F(7,25)
#  Min Obs:                                         32.000
#  Max Obs:                                         32.000   F-statistic (robust):             4.6162
#                                                            P-value                           0.0020
#  Time periods:                                        32   Distribution:                    F(7,25)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        317.40     5357.7     0.0592     0.9532  -1.072e+04   1.135e+04
#  Enterprise Value                                        52.437  1.293e+04     0.0041     0.9968  -2.657e+04   2.668e+04
#  Market Capitalization                                   443.36     9059.6     0.0489     0.9614  -1.822e+04    1.91e+04
#  loss firm status                                        0.1165     3.4091     0.0342     0.9730     -6.9046      7.1377
#  Enterprise Value To Sales (Daily Time Series Ratio)     97.761     4494.0     0.0218     0.9828     -9157.8      9353.3
#  3 Month Total Return                                   -28.673     63.387    -0.4524     0.6549     -159.22      101.87
#  Volume                                                 -4376.8     2171.8    -2.0153     0.0547     -8849.7      96.056
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887d6250,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5766
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.2096
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.5766
#  Time:                                          20:49:47   Log-likelihood                   -154.78
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      6.4193
#  Entities:                                             1   P-value                           0.0001
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             6.4193
#                                                            P-value                           0.0001
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -1794.4     1041.7    -1.7225     0.0943     -3913.8      325.06
#  Enterprise Value                                       -183.70     4449.3    -0.0413     0.9673     -9235.9      8868.5
#  Market Capitalization                                  -2248.2     3085.9    -0.7285     0.4714     -8526.6      4030.2
#  loss firm status                                       -0.3688     6.7501    -0.0546     0.9568     -14.102      13.364
#  Enterprise Value To Sales (Daily Time Series Ratio)     5422.5     5639.9     0.9615     0.3433     -6052.0    1.69e+04
#  3 Month Total Return                                   -42.473     65.643    -0.6470     0.5221     -176.03      91.080
#  Volume                                                  1097.1     1134.3     0.9672     0.3405     -1210.7      3404.8
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887c0050,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5333
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.2572
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.5333
#  Time:                                          20:49:47   Log-likelihood                   -158.45
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      5.3878
#  Entities:                                             1   P-value                           0.0003
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             5.3878
#                                                            P-value                           0.0003
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -5102.7     1826.1    -2.7943     0.0086     -8817.9     -1387.5
#  Enterprise Value                                     1.665e+04     9526.9     1.7475     0.0898     -2734.2   3.603e+04
#  Market Capitalization                               -1.547e+04     5604.7    -2.7604     0.0094  -2.687e+04     -4068.3
#  loss firm status                                       -2.6047     5.4215    -0.4804     0.6341     -13.635      8.4254
#  Enterprise Value To Sales (Daily Time Series Ratio)    -3309.3  1.004e+04    -0.3295     0.7439  -2.374e+04   1.713e+04
#  3 Month Total Return                                    22.428     46.506     0.4823     0.6328     -72.190      117.05
#  Volume                                                  122.29     771.00     0.1586     0.8749     -1446.3      1690.9
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887bd390,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4158
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.3788
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.4158
#  Time:                                          20:49:47   Log-likelihood                   -151.45
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      3.3554
#  Entities:                                             1   P-value                           0.0082
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             3.3554
#                                                            P-value                           0.0082
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        813.22     649.46     1.2521     0.2193     -508.12      2134.6
#  Enterprise Value                                       -8811.7     8783.1    -1.0032     0.3230  -2.668e+04      9057.8
#  Market Capitalization                                   4794.8     6629.3     0.7233     0.4746     -8692.6   1.828e+04
#  loss firm status                                       -21.890     6.1346    -3.5683     0.0011     -34.371     -9.4093
#  Enterprise Value To Sales (Daily Time Series Ratio)     6195.9     9444.9     0.6560     0.5164  -1.302e+04   2.541e+04
#  3 Month Total Return                                    31.021     35.503     0.8737     0.3886     -41.212      103.25
#  Volume                                                 -156.14     477.67    -0.3269     0.7458     -1128.0      815.69
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887b2710,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.3226
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.3226
# ...
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             2.6198
#                                                            P-value                           0.0345
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -8389.8     6534.2    -1.2840     0.2081  -2.168e+04      4904.2
#  Enterprise Value                                     2.988e+04  1.244e+04     2.4013     0.0221      4564.2    5.52e+04
#  Market Capitalization                               -3.272e+04  1.006e+04    -3.2512     0.0026   -5.32e+04  -1.225e+04
#  loss firm status                                        534.41     279.41     1.9126     0.0645     -34.053      1102.9
#  Enterprise Value To Sales (Daily Time Series Ratio)     8986.1     4402.3     2.0413     0.0493      29.660   1.794e+04
#  3 Month Total Return                                   -5.3338     71.967    -0.0741     0.9414     -151.75      141.08
#  Volume                                                 -3687.4     6007.3    -0.6138     0.5435  -1.591e+04      8534.4
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887befd0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.8020
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.6732
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.8020
#  Time:                                          20:49:47   Log-likelihood                   -124.85
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      19.092
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             19.092
#                                                            P-value                           0.0000
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -430.59     603.53    -0.7134     0.4806     -1658.5      797.31
#  Enterprise Value                                        1135.3     4093.2     0.2774     0.7832     -7192.3      9463.0
#  Market Capitalization                                  -470.73     3199.7    -0.1471     0.8839     -6980.5      6039.1
#  loss firm status                                        16.772     2.6419     6.3484     0.0000      11.397      22.147
#  Enterprise Value To Sales (Daily Time Series Ratio)     21.832     3699.6     0.0059     0.9953     -7505.0      7548.6
#  3 Month Total Return                                    68.440     30.110     2.2730     0.0297      7.1812      129.70
#  Volume                                                 -411.74     598.66    -0.6878     0.4964     -1629.7      806.24
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x1887eefd0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4156
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.1418
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.4156
#  Time:                                          20:49:47   Log-likelihood                   -151.25
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      3.3530
#  Entities:                                             1   P-value                           0.0082
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             3.3530
#                                                            P-value                           0.0082
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                       -1532.4     7078.5    -0.2165     0.8299  -1.593e+04   1.287e+04
#  Enterprise Value                                        6331.2  1.829e+04     0.3462     0.7314  -3.088e+04   4.354e+04
#  Market Capitalization                                  -2113.7  1.296e+04    -0.1631     0.8714  -2.848e+04   2.425e+04
#  loss firm status                                        2.2847     6.2616     0.3649     0.7175     -10.455      15.024
#  Enterprise Value To Sales (Daily Time Series Ratio)    -3250.1     4158.8    -0.7815     0.4401  -1.171e+04      5211.1
#  3 Month Total Return                                    56.059     44.201     1.2683     0.2136     -33.870      145.99
#  Volume                                                  1662.5     1143.4     1.4541     0.1554     -663.67      3988.8
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18879efd0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.2919
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.2257
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.2919
#  Time:                                          20:49:47   Log-likelihood                   -166.46
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      1.9434
#  Entities:                                             1   P-value                           0.0938
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             1.9434
#                                                            P-value                           0.0938
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        2336.4     1482.5     1.5760     0.1246     -679.76      5352.6
#  Enterprise Value                                       -4278.9     3679.9    -1.1627     0.2533  -1.177e+04      3208.1
#  Market Capitalization                                   5905.5     3613.3     1.6344     0.1117     -1445.8   1.326e+04
#  loss firm status                                        0.9388     4.4476     0.2111     0.8341     -8.1099      9.9874
#  Enterprise Value To Sales (Daily Time Series Ratio)    -3890.8     2989.9    -1.3013     0.2022     -9973.8      2192.2
#  3 Month Total Return                                    83.768     48.560     1.7250     0.0939     -15.028      182.56
#  Volume                                                  1131.8     578.81     1.9553     0.0591     -45.839      2309.4
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18870f350,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.3133
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.1221
#  Date:                                  Mon, Feb 27 2023   R-squared (Overall):              0.3133
#  Time:                                          20:49:47   Log-likelihood                   -147.57
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      2.1504
#  Entities:                                             1   P-value                           0.0653
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             2.1504
#                                                            P-value                           0.0653
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                        4628.2     3158.1     1.4655     0.1523     -1797.1   1.105e+04
#  Enterprise Value                                    -1.363e+04     9583.6    -1.4218     0.1645  -3.312e+04      5871.9
#  Market Capitalization                                   8858.3     5863.4     1.5108     0.1404     -3070.9   2.079e+04
#  loss firm status                                       -0.5272     2.3408    -0.2252     0.8232     -5.2895      4.2352
#  Enterprise Value To Sales (Daily Time Series Ratio)     3238.0     3255.2     0.9947     0.3271     -3384.8      9860.9
#  3 Month Total Return                                    8.0545     34.921     0.2306     0.8190     -62.994      79.103
#  Volume                                                  3349.6     3830.2     0.8745     0.3882     -4443.0   1.114e+04
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x188834e10]
