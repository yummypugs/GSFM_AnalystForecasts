# %% [markdown]
# # Panle Regression - Firm Characteristics

# %% [markdown]
# ### Random Effects Panel Regression

# %%
import pandas as pd
import numpy as np
import datetime as dt
import sklearn
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from linearmodels.panel import PanelOLS
from linearmodels.panel import RandomEffects

# %% [markdown]
# Data

# %%
df = pd.read_csv("Dataframes/characteristics.csv")
X_var_names = ["Revenue - Actual","Enterprise Value","Market Capitalization","loss firm status", "Enterprise Value To Sales (Daily Time Series Ratio)", "3 Month Total Return", "Volume"]
df
# Out:
#       Instrument        Date GICS Industry Group Name  \
# 0          AVY.N  2013-01-01                Materials
# 1          AVY.N  2013-04-01                Materials
# 2          AVY.N  2013-07-01                Materials
# 3          AVY.N  2013-10-01                Materials
# 4          AVY.N  2014-01-01                Materials
# ...          ...         ...                      ...
# 19335    POOL.OQ  2021-10-01                Retailing
# 19336    POOL.OQ  2022-01-01                Retailing
# 19337    POOL.OQ  2022-04-01                Retailing
# 19338    POOL.OQ  2022-07-01                Retailing
# 19339    POOL.OQ  2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  Revenue - Actual  \
# 0                                    11.178      1.532200e+09
# 1                                     2.482      1.498900e+09
# 2                                     1.068      1.552300e+09
# 3                                     8.095      1.504900e+09
# 4                                     1.471      1.583900e+09
# ...                                     ...               ...
# 19335                                17.194      1.411448e+09
# 19336                                40.267      1.035557e+09
# 19337                                34.342      1.412650e+09
# 19338                                 1.503      2.055818e+09
# 19339                                 4.196      1.615339e+09
#
#        Enterprise Value  Market Capitalization  \
# 0          4.413001e+09           3.426001e+09
# 1          5.459128e+09           4.309428e+09
# 2          5.436229e+09           4.258229e+09
# 3          5.029514e+09           4.273414e+09
# 4          5.553068e+09           4.877168e+09
# ...                 ...                    ...
# 19335      1.769954e+10           1.742020e+10
# 19336      2.384882e+10           2.268979e+10
# 19337      1.843682e+10           1.696712e+10
# 19338      1.556187e+10           1.405795e+10
# 19339      1.406160e+10           1.259813e+10
#
#        Enterprise Value To Sales (Daily Time Series Ratio)  \
# 0                                               0.799347
# 1                                               0.895787
# 2                                               0.906078
# 3                                               0.903176
# 4                                               0.920659
# ...                                                  ...
# 19335                                           3.684400
# 19336                                           4.504382
# 19337                                           3.422880
# 19338                                           2.749481
# 19339                                           2.383926
#
#        3 Month Total Return    Volume  loss firm status
# 0                 10.637479  207295.0                -1
# 1                 24.148726       0.0                -1
# 2                 -0.054218       0.0                -1
# 3                  2.467620  236291.0                -1
# 4                 16.003852  157761.0                -1
# ...                     ...       ...               ...
# 19335             -5.130322  157740.0                -1
# 19336             30.489705   82349.0                -1
# 19337            -25.160664  290897.0                -1
# 19338            -21.661570  185584.0                -1
# 19339             -9.164375  238539.0                -1
#
# [19340 rows x 11 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %% [markdown]
# Remove outliers

# %%
#removing outliers
summary_stats = df["Earnings Per Share - Actual Surprise"].describe()
Q1 = summary_stats.loc['25%']
Q3 = summary_stats.loc['75%']
IQR = Q3 - Q1
threshold = 7
surprise_outliers_removed = df["Earnings Per Share - Actual Surprise"].loc[~((df["Earnings Per Share - Actual Surprise"] < (Q1 - threshold * IQR)) | (df["Earnings Per Share - Actual Surprise"] > (Q3 + threshold * IQR)))]
df_clean = df.copy()
df_clean["Earnings Per Share - Actual Surprise"] = surprise_outliers_removed
df_clean = df_clean.dropna(subset=["Earnings Per Share - Actual Surprise"])
#df_clean = df_clean.dropna()
df_panel = df_clean.copy()
df_clean
# Out:
#       Instrument       Date GICS Industry Group Name  \
# 0          AVY.N 2013-01-01                Materials
# 1          AVY.N 2013-04-01                Materials
# 2          AVY.N 2013-07-01                Materials
# 3          AVY.N 2013-10-01                Materials
# 4          AVY.N 2014-01-01                Materials
# ...          ...        ...                      ...
# 19335    POOL.OQ 2021-10-01                Retailing
# 19336    POOL.OQ 2022-01-01                Retailing
# 19337    POOL.OQ 2022-04-01                Retailing
# 19338    POOL.OQ 2022-07-01                Retailing
# 19339    POOL.OQ 2022-10-01                Retailing
#
#        Earnings Per Share - Actual Surprise  Revenue - Actual  \
# 0                                    11.178      1.532200e+09
# 1                                     2.482      1.498900e+09
# 2                                     1.068      1.552300e+09
# 3                                     8.095      1.504900e+09
# 4                                     1.471      1.583900e+09
# ...                                     ...               ...
# 19335                                17.194      1.411448e+09
# 19336                                40.267      1.035557e+09
# 19337                                34.342      1.412650e+09
# 19338                                 1.503      2.055818e+09
# 19339                                 4.196      1.615339e+09
#
#        Enterprise Value  Market Capitalization  \
# 0          4.413001e+09           3.426001e+09
# 1          5.459128e+09           4.309428e+09
# 2          5.436229e+09           4.258229e+09
# 3          5.029514e+09           4.273414e+09
# 4          5.553068e+09           4.877168e+09
# ...                 ...                    ...
# 19335      1.769954e+10           1.742020e+10
# 19336      2.384882e+10           2.268979e+10
# 19337      1.843682e+10           1.696712e+10
# 19338      1.556187e+10           1.405795e+10
# 19339      1.406160e+10           1.259813e+10
#
#        Enterprise Value To Sales (Daily Time Series Ratio)  \
# 0                                               0.799347
# 1                                               0.895787
# 2                                               0.906078
# 3                                               0.903176
# 4                                               0.920659
# ...                                                  ...
# 19335                                           3.684400
# 19336                                           4.504382
# 19337                                           3.422880
# 19338                                           2.749481
# 19339                                           2.383926
#
#        3 Month Total Return    Volume  loss firm status
# 0                 10.637479  207295.0                -1
# 1                 24.148726       0.0                -1
# 2                 -0.054218       0.0                -1
# 3                  2.467620  236291.0                -1
# 4                 16.003852  157761.0                -1
# ...                     ...       ...               ...
# 19335             -5.130322  157740.0                -1
# 19336             30.489705   82349.0                -1
# 19337            -25.160664  290897.0                -1
# 19338            -21.661570  185584.0                -1
# 19339             -9.164375  238539.0                -1
#
# [18569 rows x 11 columns]

# %% [markdown]
# #### Random Effects

# %%
# turn dataframe into right dimension for panel regression with multiindex
df_clean['Instrument'] = df_clean['Instrument'].astype('category')
df_clean['Date'] = pd.to_datetime(df_clean['Date'])

# set the index to be the time variable and the cross-sectional variable
df_clean.set_index(['Instrument', 'Date'], inplace=True)

# define the dependent variable



# perform the random effects panel regression
random_effects_model = RandomEffects(y, X)

# fit the model and print the summary statistics
random_effects_results = random_effects_model.fit()
print(random_effects_results.summary)
# Out:
#                                  RandomEffects Estimation Summary
# ==================================================================================================
# Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.0030
# Estimator:                                RandomEffects   R-squared (Between):             -0.3708
# No. Observations:                                 18569   R-squared (Within):               0.0112
# Date:                                  Sun, Feb 26 2023   R-squared (Overall):             -0.0274
# Time:                                          21:44:22   Log-likelihood                -7.829e+04
# Cov. Estimator:                              Unadjusted
#                                                           F-statistic:                      9.1615
# Entities:                                           501   P-value                           0.0000
# Avg Obs:                                         37.064   Distribution:                 F(6,18562)
# Min Obs:                                         6.0000
# Max Obs:                                         40.000   F-statistic (robust):             120.36
#                                                           P-value                           0.0000
# Time periods:                                        41   Distribution:                 F(6,18562)
# Avg Obs:                                         452.90
# Min Obs:                                         47.000
# Max Obs:                                         490.00
#
#                                                   Parameter Estimates
# =======================================================================================================================
#                                                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------------------------------------
# Revenue - Actual                                     1.065e-10  2.373e-11     4.4867     0.0000   5.996e-11    1.53e-10
# Enterprise Value                                     6.487e-12   6.71e-12     0.9668     0.3337  -6.665e-12   1.964e-11
# Market Capitalization                               -1.836e-12   6.81e-12    -0.2696     0.7875  -1.518e-11   1.151e-11
# loss firm status                                       -2.9972     0.2094    -14.317     0.0000     -3.4076     -2.5869
# Enterprise Value To Sales (Daily Time Series Ratio)     0.0154     0.0123     1.2523     0.2105     -0.0087      0.0395
# 3 Month Total Return                                    0.1325     0.0082     16.186     0.0000      0.1165      0.1486
# Volume                                               1.911e-07   4.96e-08     3.8528     0.0001   9.387e-08   2.883e-07
# =======================================================================================================================

# %% [markdown]
# **R-squared (Within)**: This is the proportion of variation in the dependent variable (in your case, Earnings Per Share - Actual Surprise) that is explained by the independent variables (in our case, the variables in X) within each individual instrument (the 501 companies). In other words, this R-squared measures how well the independent variables explain the variation in the dependent variable (surprise) within each instrument. The R-squared (Within) is 0.0112, which means that the independent variables explain only about 1.12% of the variation in the dependent variable within each instrument.
#
# **R-squared (Between)**: This is the proportion of variation in the dependent variable that is explained by the independent variables across the instruments. In other words, this R-squared measures how well the independent variables explain the variation in the dependent variable between different instruments. The R-squared (Between) is -0.3708, which means that the independent variables actually perform worse than just using the mean of the dependent variable for each instrument to explain the variation in the dependent variable across entities.
#
# **R-squared (Overall)**: This is the proportion of variation in the dependent variable that is explained by the independent variables overall, taking into account both the within-instrument and between-instrument variation. The R-squared (Overall) is -0.0274, which means that the independent variables explain only about 2.74% of the variation in the dependent variable overall.

# %% [markdown]
# #### Fixed Effects

# %%
y = df_clean.loc[:, "Earnings Per Share - Actual Surprise"]
X = df_clean[X_var_names]

# perform the fixed effects panel regression
fixed_effects_model = PanelOLS(y, X, entity_effects=True, time_effects=True)

# fit the model and print the summary statistics
fixed_effects_results = fixed_effects_model.fit()
fixed_effects_results.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                                    PanelOLS Estimation Summary
# ==================================================================================================
# Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                       -0.0029
# Estimator:                                     PanelOLS   R-squared (Between):             -0.8660
# No. Observations:                                 18569   R-squared (Within):               0.0056
# Date:                                  Sun, Feb 26 2023   R-squared (Overall):             -0.0932
# Time:                                          21:44:22   Log-likelihood                -7.773e+04
# Cov. Estimator:                              Unadjusted
#                                                           F-statistic:                     -8.6700
# Entities:                                           501   P-value                           1.0000
# Avg Obs:                                         37.064   Distribution:                 F(6,18022)
# Min Obs:                                         6.0000
# Max Obs:                                         40.000   F-statistic (robust):             482.92
#                                                           P-value                           0.0000
# Time periods:                                        41   Distribution:                 F(6,18022)
# Avg Obs:                                         452.90
# Min Obs:                                         47.000
# Max Obs:                                         490.00
#
#                                                   Parameter Estimates
# =======================================================================================================================
#                                                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -----------------------------------------------------------------------------------------------------------------------
# Revenue - Actual                                     4.557e-10  3.635e-11     12.538     0.0000   3.844e-10   5.269e-10
# Enterprise Value                                     1.661e-11  1.021e-11     1.6272     0.1037  -3.398e-12   3.662e-11
# Market Capitalization                               -2.057e-11  1.034e-11    -1.9895     0.0467  -4.083e-11  -3.035e-13
# loss firm status                                       -3.6511     0.2052    -17.794     0.0000     -4.0533     -3.2489
# Enterprise Value To Sales (Daily Time Series Ratio)    -0.0093     0.0125    -0.7462     0.4556     -0.0339      0.0152
# 3 Month Total Return                                    0.1038     0.0093     11.160     0.0000      0.0855      0.1220
# Volume                                                1.94e-07  5.415e-08     3.5819     0.0003   8.782e-08   3.001e-07
# =======================================================================================================================
#
# F-test for Poolability: 5.6197
# P-value: 0.0000
# Distribution: F(540,18022)
#
# Included effects: Entity, Time
# """

# %% [markdown]
# By Industry: example tech industry

# %%
df2 = df_panel[df_panel['GICS Industry Group Name'] == 'Technology Hardware & Equipment']
groups = df2.groupby('Instrument')

def panel_regression_random(group):
    if len(group) < 2:
        return None
    
    group['Instrument'] = group['Instrument'].astype('category')
    group['Date'] = pd.to_datetime(group['Date'])
    group.set_index(['Instrument', 'Date'], inplace=True)

    y = group.loc[:, "Earnings Per Share - Actual Surprise"]
    X = group[X_var_names]

    model = RandomEffects(y, X).fit()
    return model


results_random = groups.apply(panel_regression_random)
results_random = results_random.dropna()
models_random = results_random.tolist()
models_random
# Out:
# [                                 RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4285
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.4285
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.4285
#  Time:                                          21:45:10   Log-likelihood                   -132.40
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.1245
#  Entities:                                             1   P-value                           0.0034
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             4.1245
#                                                            P-value                           0.0034
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -2.744e-11  9.242e-11    -0.2969     0.7684  -2.155e-10   1.606e-10
#  Enterprise Value                                    -7.012e-12  6.596e-11    -0.1063     0.9160  -1.412e-10   1.272e-10
#  Market Capitalization                               -1.091e-11   6.88e-11    -0.1586     0.8750  -1.509e-10   1.291e-10
#  loss firm status                                        13.486     5.8232     2.3160     0.0269      1.6389      25.334
#  Enterprise Value To Sales (Daily Time Series Ratio)     10.117     2.6843     3.7690     0.0006      4.6559      15.578
#  3 Month Total Return                                   -0.0768     0.0871    -0.8813     0.3845     -0.2541      0.1005
#  Volume                                               1.349e-08  5.338e-08     0.2527     0.8021  -9.511e-08   1.221e-07
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d78f090,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.8637
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    33   R-squared (Within):               0.5530
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.8637
#  Time:                                          21:45:10   Log-likelihood                   -112.25
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      23.533
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         33.000   Distribution:                    F(7,26)
#  Min Obs:                                         33.000
#  Max Obs:                                         33.000   F-statistic (robust):             23.533
#                                                            P-value                           0.0000
#  Time periods:                                        33   Distribution:                    F(7,26)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     4.205e-08  1.547e-08     2.7178     0.0115   1.025e-08   7.385e-08
#  Enterprise Value                                     5.978e-09  3.712e-09     1.6104     0.1194  -1.652e-09   1.361e-08
#  Market Capitalization                               -7.369e-09  3.476e-09    -2.1201     0.0437  -1.451e-08  -2.243e-10
#  loss firm status                                       -2.5993     3.9727    -0.6543     0.5187     -10.765      5.5667
#  Enterprise Value To Sales (Daily Time Series Ratio)     3.3756     0.6437     5.2441     0.0000      2.0525      4.6988
#  3 Month Total Return                                    0.0002     0.0732     0.0032     0.9975     -0.1503      0.1508
#  Volume                                              -6.982e-07  5.581e-06    -0.1251     0.9014  -1.217e-05   1.077e-05
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d791c90,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4378
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.4378
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.4378
#  Time:                                          21:45:10   Log-likelihood                   -118.09
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.2823
#  Entities:                                             1   P-value                           0.0027
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             4.2823
#                                                            P-value                           0.0027
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     1.659e-08  7.456e-09     2.2248     0.0330   1.419e-09   3.176e-08
#  Enterprise Value                                     -1.54e-09  2.164e-09    -0.7116     0.4817  -5.942e-09   2.862e-09
#  Market Capitalization                                6.529e-10  2.371e-09     0.2754     0.7847  -4.171e-09   5.477e-09
#  loss firm status                                        26.068     13.999     1.8622     0.0715     -2.4126      54.548
#  Enterprise Value To Sales (Daily Time Series Ratio)     6.3654     4.4081     1.4440     0.1582     -2.6031      15.334
#  3 Month Total Return                                    0.2642     0.0922     2.8660     0.0072      0.0766      0.4517
#  Volume                                               2.388e-06  1.545e-06     1.5463     0.1316   -7.54e-07   5.531e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d793fd0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.6959
#  Estimator:                                RandomEffects   R-squared (Between):              0.9998
#  No. Observations:                                    36   R-squared (Within):               0.0690
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.6959
#  Time:                                          21:45:10   Log-likelihood                   -112.05
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      9.4807
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         36.000   Distribution:                    F(7,29)
#  Min Obs:                                         36.000
#  Max Obs:                                         36.000   F-statistic (robust):             9.4807
#                                                            P-value                           0.0000
#  Time periods:                                        36   Distribution:                    F(7,29)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                      2.66e-09  3.411e-09     0.7798     0.4418  -4.317e-09   9.637e-09
#  Enterprise Value                                    -2.536e-09  1.951e-09    -1.2997     0.2040  -6.526e-09   1.455e-09
#  Market Capitalization                                2.128e-09  1.783e-09     1.1940     0.2422  -1.517e-09   5.774e-09
#  loss firm status                                       -1.4757     3.4092    -0.4329     0.6683     -8.4483      5.4968
#  Enterprise Value To Sales (Daily Time Series Ratio)     8.2489     12.923     0.6383     0.5283     -18.181      34.678
#  3 Month Total Return                                    0.0774     0.1137     0.6804     0.5016     -0.1552      0.3099
#  Volume                                                1.68e-06  4.726e-06     0.3555     0.7248  -7.985e-06   1.135e-05
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d7a2610,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.2207
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.2207
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.2207
#  Time:                                          21:45:10   Log-likelihood                   -90.217
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      1.5576
#  Entities:                                             1   P-value                           0.1907
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             1.5576
#                                                            P-value                           0.1907
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -1.707e-09  9.577e-10    -1.7821     0.0839  -3.655e-09   2.417e-10
#  Enterprise Value                                     1.432e-10  8.573e-11     1.6699     0.1044  -3.126e-11   3.176e-10
#  Market Capitalization                                -1.34e-10  8.485e-11    -1.5789     0.1239  -3.066e-10   3.866e-11
#  loss firm status                                       -31.121     12.386    -2.5126     0.0171     -56.321     -5.9212
#  Enterprise Value To Sales (Daily Time Series Ratio)    -1.7136     1.9672    -0.8711     0.3900     -5.7159      2.2887
#  3 Month Total Return                                    0.0213     0.0481     0.4433     0.6605     -0.0766      0.1192
#  Volume                                               9.359e-08  1.233e-07     0.7589     0.4533  -1.573e-07   3.445e-07
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d29ae90,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.2909
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.2909
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.2909
#  Time:                                          21:45:10   Log-likelihood                   -105.15
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      2.2562
#  Entities:                                             1   P-value                           0.0620
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             2.2562
#                                                            P-value                           0.0620
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     3.049e-08  2.648e-08     1.1513     0.2579  -2.339e-08   8.436e-08
#  Enterprise Value                                     5.431e-09  3.076e-09     1.7655     0.0867  -8.274e-10   1.169e-08
#  Market Capitalization                               -6.403e-09  2.923e-09    -2.1906     0.0357  -1.235e-08  -4.562e-10
#  loss firm status                                        1.2554     14.779     0.0850     0.9328     -28.812      31.323
#  Enterprise Value To Sales (Daily Time Series Ratio)     0.9904     3.2747     0.3024     0.7642     -5.6722      7.6529
#  3 Month Total Return                                   -0.0181     0.0463    -0.3902     0.6989     -0.1122      0.0761
#  Volume                                               -5.63e-06  4.782e-06    -1.1773     0.2475  -1.536e-05   4.099e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d6e3510,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5610
#  Estimator:                                RandomEffects   R-squared (Between):              0.9996
#  No. Observations:                                    39   R-squared (Within):               0.1164
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.5610
#  Time:                                          21:45:10   Log-likelihood                   -123.11
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      5.8423
#  Entities:                                             1   P-value                           0.0002
#  Avg Obs:                                         39.000   Distribution:                    F(7,32)
#  Min Obs:                                         39.000
#  Max Obs:                                         39.000   F-statistic (robust):             5.8423
#                                                            P-value                           0.0002
#  Time periods:                                        39   Distribution:                    F(7,32)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     8.936e-09  4.352e-09     2.0532     0.0483   7.099e-11    1.78e-08
#  Enterprise Value                                     -1.02e-09  5.144e-10    -1.9836     0.0559  -2.068e-09   2.743e-11
#  Market Capitalization                               -4.757e-10  5.695e-10    -0.8353     0.4097  -1.636e-09   6.843e-10
#  loss firm status                                        1.2481     2.2702     0.5498     0.5863     -3.3762      5.8724
#  Enterprise Value To Sales (Daily Time Series Ratio)     8.7776     3.7003     2.3721     0.0239      1.2403      16.315
#  3 Month Total Return                                    0.0837     0.1051     0.7958     0.4320     -0.1305      0.2978
#  Volume                                              -5.653e-07  9.786e-07    -0.5777     0.5675  -2.559e-06   1.428e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d6f4950,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.6082
#  Estimator:                                RandomEffects   R-squared (Between):              0.9995
#  No. Observations:                                    27   R-squared (Within):               0.3963
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.6082
#  Time:                                          21:45:10   Log-likelihood                   -102.49
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.4351
#  Entities:                                             1   P-value                           0.0040
#  Avg Obs:                                         27.000   Distribution:                    F(7,20)
#  Min Obs:                                         27.000
#  Max Obs:                                         27.000   F-statistic (robust):             4.4351
#                                                            P-value                           0.0040
#  Time periods:                                        27   Distribution:                    F(7,20)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -2.074e-09  2.441e-09    -0.8499     0.4055  -7.165e-09   3.017e-09
#  Enterprise Value                                     1.269e-09  1.445e-09     0.8783     0.3902  -1.745e-09   4.284e-09
#  Market Capitalization                                -5.89e-10  9.517e-10    -0.6189     0.5430  -2.574e-09   1.396e-09
#  loss firm status                                       -6.6632     4.0809    -1.6328     0.1182     -15.176      1.8494
#  Enterprise Value To Sales (Daily Time Series Ratio)    -1.1379     24.555    -0.0463     0.9635     -52.359      50.083
#  3 Month Total Return                                    0.3590     0.2022     1.7754     0.0910     -0.0628      0.7808
#  Volume                                              -1.985e-06  1.912e-06    -1.0382     0.3116  -5.975e-06   2.004e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d4bb990,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4944
#  Estimator:                                RandomEffects   R-squared (Between):              0.9978
#  No. Observations:                                    40   R-squared (Within):               0.3681
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.4944
#  Time:                                          21:45:10   Log-likelihood                   -138.76
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.6102
#  Entities:                                             1   P-value                           0.0011
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             4.6102
#                                                            P-value                           0.0011
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     1.887e-09  6.726e-10     2.8059     0.0084   5.188e-10   3.256e-09
#  Enterprise Value                                    -1.441e-09  7.512e-10    -1.9176     0.0639  -2.969e-09   8.783e-11
#  Market Capitalization                                6.408e-10  6.621e-10     0.9679     0.3401  -7.062e-10   1.988e-09
#  loss firm status                                       -4.5011     4.4021    -1.0225     0.3140     -13.457      4.4550
#  Enterprise Value To Sales (Daily Time Series Ratio)     2.2345     2.4079     0.9280     0.3601     -2.6644      7.1334
#  3 Month Total Return                                    0.0612     0.0947     0.6465     0.5224     -0.1314      0.2538
#  Volume                                               2.136e-07  6.917e-07     0.3088     0.7594  -1.194e-06   1.621e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d7546d0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.6380
#  Estimator:                                RandomEffects   R-squared (Between):              1.0000
#  No. Observations:                                    40   R-squared (Within):               0.4129
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.6380
#  Time:                                          21:45:10   Log-likelihood                   -136.72
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      8.3089
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             8.3089
#                                                            P-value                           0.0000
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     1.906e-08  1.088e-08     1.7525     0.0890  -3.067e-09   4.119e-08
#  Enterprise Value                                    -6.273e-09   3.51e-09    -1.7869     0.0831  -1.342e-08   8.692e-10
#  Market Capitalization                                3.319e-09  1.837e-09     1.8069     0.0799  -4.181e-10   7.057e-09
#  loss firm status                                        10.333     3.1337     3.2972     0.0023      3.9569      16.708
#  Enterprise Value To Sales (Daily Time Series Ratio)     9.8597     16.291     0.6052     0.5492     -23.285      43.005
#  3 Month Total Return                                    0.2808     0.1459     1.9253     0.0628     -0.0159      0.5776
#  Volume                                              -3.863e-07  2.453e-06    -0.1575     0.8758  -5.377e-06   4.604e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d76d850,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5607
#  Estimator:                                RandomEffects   R-squared (Between):              0.9999
#  No. Observations:                                    32   R-squared (Within):               0.1895
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.5607
#  Time:                                          21:45:10   Log-likelihood                   -120.88
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      4.5588
#  Entities:                                             1   P-value                           0.0021
#  Avg Obs:                                         32.000   Distribution:                    F(7,25)
#  Min Obs:                                         32.000
#  Max Obs:                                         32.000   F-statistic (robust):             4.5588
#                                                            P-value                           0.0021
#  Time periods:                                        32   Distribution:                    F(7,25)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     1.665e-08  1.722e-08     0.9668     0.3429  -1.881e-08    5.21e-08
#  Enterprise Value                                     1.837e-09  8.598e-09     0.2137     0.8325  -1.587e-08   1.954e-08
#  Market Capitalization                               -2.133e-09  8.029e-09    -0.2657     0.7927  -1.867e-08    1.44e-08
#  loss firm status                                       -1.0953     4.0288    -0.2719     0.7880     -9.3928      7.2022
#  Enterprise Value To Sales (Daily Time Series Ratio)     1.0661     5.1084     0.2087     0.8364     -9.4549      11.587
#  3 Month Total Return                                   -0.0753     0.1986    -0.3789     0.7080     -0.4844      0.3339
#  Volume                                              -2.114e-05  1.113e-05    -1.8992     0.0691  -4.406e-05   1.785e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d75c350,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.5167
#  Estimator:                                RandomEffects   R-squared (Between):              0.9975
#  No. Observations:                                    40   R-squared (Within):               0.1000
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.5167
#  Time:                                          21:45:10   Log-likelihood                   -157.43
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      5.0407
#  Entities:                                             1   P-value                           0.0006
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             5.0407
#                                                            P-value                           0.0006
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -4.185e-09   6.46e-09    -0.6479     0.5215  -1.733e-08   8.957e-09
#  Enterprise Value                                    -9.896e-10  1.581e-09    -0.6261     0.5356  -4.206e-09   2.226e-09
#  Market Capitalization                               -2.735e-10  1.502e-09    -0.1821     0.8566  -3.329e-09   2.782e-09
#  loss firm status                                       -7.0444     6.6154    -1.0649     0.2947     -20.504      6.4147
#  Enterprise Value To Sales (Daily Time Series Ratio)     11.237     7.5195     1.4943     0.1446     -4.0619      26.535
#  3 Month Total Return                                   -0.1319     0.2220    -0.5943     0.5564     -0.5836      0.3197
#  Volume                                               1.156e-05  6.464e-06     1.7887     0.0828  -1.589e-06   2.471e-05
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d82c3d0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4309
#  Estimator:                                RandomEffects   R-squared (Between):              0.9986
#  No. Observations:                                    40   R-squared (Within):               0.0950
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.4309
#  Time:                                          21:45:10   Log-likelihood                   -162.41
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      3.5697
#  Entities:                                             1   P-value                           0.0058
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             3.5697
#                                                            P-value                           0.0058
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     1.819e-08  1.364e-08     1.3331     0.1916   -9.57e-09   4.595e-08
#  Enterprise Value                                     4.443e-09  3.622e-09     1.2267     0.2286  -2.926e-09   1.181e-08
#  Market Capitalization                               -5.366e-09  3.098e-09    -1.7322     0.0926  -1.167e-08   9.366e-10
#  loss firm status                                       -2.0367     6.0175    -0.3385     0.7372     -14.279      10.206
#  Enterprise Value To Sales (Daily Time Series Ratio)     1.6447     13.357     0.1231     0.9027     -25.531      28.820
#  3 Month Total Return                                    0.0942     0.1638     0.5752     0.5691     -0.2391      0.4275
#  Volume                                               3.578e-06  4.745e-06     0.7541     0.4561  -6.075e-06   1.323e-05
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d838150,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.3858
#  Estimator:                                RandomEffects   R-squared (Between):              0.9931
#  No. Observations:                                    40   R-squared (Within):               0.3473
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.3858
#  Time:                                          21:45:10   Log-likelihood                   -152.45
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      2.9613
#  Entities:                                             1   P-value                           0.0160
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             2.9613
#                                                            P-value                           0.0160
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     1.059e-09  3.807e-09     0.2782     0.7826  -6.686e-09   8.803e-09
#  Enterprise Value                                    -3.835e-09  2.885e-09    -1.3293     0.1929  -9.706e-09   2.035e-09
#  Market Capitalization                                2.345e-09  2.399e-09     0.9777     0.3353  -2.535e-09   7.225e-09
#  loss firm status                                       -19.819     6.2236    -3.1845     0.0032     -32.481     -7.1569
#  Enterprise Value To Sales (Daily Time Series Ratio)     9.6327     13.719     0.7022     0.4875     -18.278      37.544
#  3 Month Total Return                                    0.0996     0.1152     0.8648     0.3934     -0.1348      0.3341
#  Volume                                               -1.34e-06  2.772e-06    -0.4834     0.6320  -6.979e-06   4.299e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d83d050,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.3226
#  Estimator:                                RandomEffects   R-squared (Between):              0.0000
#  No. Observations:                                    40   R-squared (Within):               0.3226
# ...
#  Avg Obs:                                         40.000   Distribution:                    F(6,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             2.6198
#                                                            P-value                           0.0345
#  Time periods:                                        40   Distribution:                    F(6,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -5.183e-08  4.036e-08    -1.2840     0.2081  -1.339e-07    3.03e-08
#  Enterprise Value                                     9.859e-09  4.106e-09     2.4013     0.0221   1.506e-09   1.821e-08
#  Market Capitalization                               -1.131e-08   3.48e-09    -3.2512     0.0026  -1.839e-08  -4.234e-09
#  loss firm status                                       -22.813     21.205    -1.0758     0.2898     -65.955      20.329
#  Enterprise Value To Sales (Daily Time Series Ratio)     10.601     5.1934     2.0413     0.0493      0.0350      21.167
#  3 Month Total Return                                   -0.0169     0.2278    -0.0741     0.9414     -0.4802      0.4465
#  Volume                                              -2.104e-05  3.427e-05    -0.6138     0.5435  -9.076e-05   4.869e-05
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d844b10,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.8002
#  Estimator:                                RandomEffects   R-squared (Between):              0.9999
#  No. Observations:                                    40   R-squared (Within):               0.6703
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.8002
#  Time:                                          21:45:10   Log-likelihood                   -125.03
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      18.883
#  Entities:                                             1   P-value                           0.0000
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             18.883
#                                                            P-value                           0.0000
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                     4.309e-09  1.865e-09     2.3105     0.0273   5.147e-10   8.103e-09
#  Enterprise Value                                      1.36e-09  1.555e-09     0.8746     0.3881  -1.804e-09   4.524e-09
#  Market Capitalization                               -1.693e-09  1.484e-09    -1.1409     0.2621  -4.711e-09   1.326e-09
#  loss firm status                                        17.379     2.6029     6.6768     0.0000      12.083      22.675
#  Enterprise Value To Sales (Daily Time Series Ratio)     5.3036     4.7423     1.1184     0.2715     -4.3447      14.952
#  3 Month Total Return                                    0.2700     0.0916     2.9474     0.0058      0.0836      0.4563
#  Volume                                               4.931e-07  3.358e-06     0.1469     0.8841  -6.338e-06   7.324e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d84ced0,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.4463
#  Estimator:                                RandomEffects   R-squared (Between):              0.9999
#  No. Observations:                                    40   R-squared (Within):               0.1869
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.4463
#  Time:                                          21:45:10   Log-likelihood                   -150.17
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      3.8005
#  Entities:                                             1   P-value                           0.0039
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             3.8005
#                                                            P-value                           0.0039
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -1.792e-09  1.962e-08    -0.0914     0.9278   -4.17e-08   3.812e-08
#  Enterprise Value                                     6.153e-09  5.025e-09     1.2247     0.2294  -4.069e-09   1.638e-08
#  Market Capitalization                               -5.983e-09  5.237e-09    -1.1425     0.2615  -1.664e-08   4.672e-09
#  loss firm status                                        3.8326     5.8511     0.6550     0.5170     -8.0716      15.737
#  Enterprise Value To Sales (Daily Time Series Ratio)     0.0809     3.8092     0.0212     0.9832     -7.6690      7.8309
#  3 Month Total Return                                    0.1577     0.1319     1.1960     0.2402     -0.1106      0.4261
#  Volume                                               1.086e-05  6.098e-06     1.7808     0.0842  -1.547e-06   2.327e-05
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d854410,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.2196
#  Estimator:                                RandomEffects   R-squared (Between):              0.9935
#  No. Observations:                                    40   R-squared (Within):               0.1472
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.2196
#  Time:                                          21:45:10   Log-likelihood                   -168.41
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      1.3267
#  Entities:                                             1   P-value                           0.2691
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             1.3267
#                                                            P-value                           0.2691
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -2.133e-09  3.914e-09    -0.5451     0.5893   -1.01e-08   5.829e-09
#  Enterprise Value                                    -1.098e-10  1.067e-09    -0.1029     0.9187  -2.281e-09   2.061e-09
#  Market Capitalization                               -3.464e-12  1.011e-09    -0.0034     0.9973  -2.061e-09   2.054e-09
#  loss firm status                                       -3.3848     4.0715    -0.8313     0.4118     -11.668      4.8987
#  Enterprise Value To Sales (Daily Time Series Ratio)     10.150     17.524     0.5792     0.5664     -25.503      45.804
#  3 Month Total Return                                    0.2084     0.1658     1.2571     0.2175     -0.1289      0.5458
#  Volume                                               1.806e-06  2.788e-06     0.6476     0.5217  -3.867e-06   7.478e-06
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d85df90,
#                                   RandomEffects Estimation Summary
#  ==================================================================================================
#  Dep. Variable:     Earnings Per Share - Actual Surprise   R-squared:                        0.2942
#  Estimator:                                RandomEffects   R-squared (Between):              0.9962
#  No. Observations:                                    40   R-squared (Within):               0.0987
#  Date:                                  Sun, Feb 26 2023   R-squared (Overall):              0.2942
#  Time:                                          21:45:11   Log-likelihood                   -148.12
#  Cov. Estimator:                              Unadjusted
#                                                            F-statistic:                      1.9646
#  Entities:                                             1   P-value                           0.0904
#  Avg Obs:                                         40.000   Distribution:                    F(7,33)
#  Min Obs:                                         40.000
#  Max Obs:                                         40.000   F-statistic (robust):             1.9646
#                                                            P-value                           0.0904
#  Time periods:                                        40   Distribution:                    F(7,33)
#  Avg Obs:                                         1.0000
#  Min Obs:                                         1.0000
#  Max Obs:                                         1.0000
#
#                                                    Parameter Estimates
#  =======================================================================================================================
#                                                       Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------------------
#  Revenue - Actual                                    -8.249e-09   1.72e-08    -0.4796     0.6347  -4.325e-08   2.675e-08
#  Enterprise Value                                     3.609e-09  4.905e-09     0.7359     0.4670   -6.37e-09   1.359e-08
#  Market Capitalization                               -3.271e-09  4.405e-09    -0.7427     0.4629  -1.223e-08    5.69e-09
#  loss firm status                                       -2.4061     3.3551    -0.7171     0.4783     -9.2321      4.4199
#  Enterprise Value To Sales (Daily Time Series Ratio)     0.5854     2.5230     0.2320     0.8179     -4.5476      5.7185
#  3 Month Total Return                                   -0.0131     0.1214    -0.1082     0.9145     -0.2601      0.2338
#  Volume                                               1.673e-05  2.216e-05     0.7552     0.4555  -2.834e-05   6.181e-05
#  =======================================================================================================================
#  RandomEffectsResults, id: 0x18d866310]
